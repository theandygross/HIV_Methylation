# %% [markdown]
# # HIV Methylation Age: Model Comparison

# %%
import NotebookImport
from Age_Models_All_Patients import *
# Out:
# importing IPython notebook from <a href='./Age_Models_All_Patients.ipynb' target='_blank'>Age_Models_All_Patients</a>
# importing IPython notebook from <a href='./Setup/Imports.ipynb' target='_blank'>Setup/Imports</a>
# Populating the interactive namespace from numpy and matplotlib
# importing IPython notebook from <a href='./Setup/MethylationAgeModels.ipynb' target='_blank'>Setup/MethylationAgeModels</a>
# importing IPython notebook from <a href='./Setup/Read_HIV_Data.ipynb' target='_blank'>Setup/Read_HIV_Data</a>

# %%
groups = (duration.str.startswith('HIV')).combine_first(labels)
groups = groups.ix[groups != 's2']

# %%
pts = ti(in_set).diff(ti(study.isin(['HIV Short','HIV Long'])))
m1_adj, m2_adj, mc_adj = two_step_adjustment(pred, pred_horvath, age, labels.ix[pts])

# %%
from Setup.Imports import *

# %%
plot_regression(m1_adj, m2_adj)

# %%
diff = ((m1_adj - m2_adj) / ((m1_adj + m2_adj) * .5)).abs()
diff.hist()

# %%
violin_plot_pandas(labels, diff)

# %%
o = ti(diff > .2)
len(o)
# Out:
# 34

# %%
series_scatter??

# %%
reg = linear_regression(age, pred_c)
regression_string(reg)
# Out:
# '$r=.9$\n$y=.77x +11.6$'

# %%
def plot_regression(x, y, ax=None, **plot_args):
    x,y = match_series(x,y)
    fig, ax = init_ax(ax, figsize=(5,5))
    series_scatter(x,y, ax=ax, ann=None ,
                   **plot_args)
    reg = linear_regression(x, y)
    ax.annotate(regression_string(reg).split()[0], (.5,.05), 
                xycoords='axes fraction', size=18)    
    line_me(reg['slope'], reg['intercept'], start=x.min(),
            end=x.max(), ax=ax)
    line_me(1, 0, start=x.min(),
            end=x.max(), ax=ax)
    
    xy = x.append(y)
    ax.set_xbound(xy.min() - 3, xy.max() + 3)
    ax.set_ybound(xy.min() - 3, xy.max() + 3)
    prettify_ax(ax)

# %%
pts = ti(diff < .2)
m1_adj_c, m2_adj_c, mc_adj_c = two_step_adjustment(pred, pred_horvath, age, labels.ix[pts])
mc_adj_c.name = 'Combined, Filtered'

# %%
fig, axs = subplots(1,3, figsize=(15,4))

plot_regression(age.ix[ti(labels == 's1')], mc_adj_c, ax=axs[0])
plot_regression(age.ix[ti(labels == 's3')], mc_adj_c, axs[1])
plot_regression(age.ix[ti(labels == 's2')], mc_adj_c, axs[2])

# %%
dd = pd.DataFrame({(s, m.name): model_fit(m.ix[ti(l2 == s)], age) for s in l2.unique()
                  for m in [m1_adj, m2_adj, mc_adj, mc_adj_c]})
dd = dd.unstack().unstack(1).T
dd
# Out:
#                           EPIC                                Hannum                                Primary Cohort
#                              n     r  error (years)  % error       n     r  error (years)  % error               n     r  error (years)  % error
# Combined, Filtered         170  0.75           3.65     0.06     222  0.87           3.85     0.08              44  0.95           3.07     0.07
# Predicted Age (Combined)   182  0.76           3.60     0.07     242  0.87           4.02     0.08              46  0.94           3.29     0.08
# predicted age (Hannum)     182  0.76           3.64     0.06     242  0.88           4.08     0.08              46  0.93           3.59     0.08
# predicted age (Horvath)    182  0.66           4.66     0.09     242  0.81           5.00     0.10              46  0.93           3.55     0.08

# %%
(mc_adj_c / age).dropna().hist(bins=30)

# %% [markdown]
# ### Filter one sketchy subject

# %%
pts = ti((mc_adj_c / age) < 2)
m1_adj_c, m2_adj_c, mc_adj_c = two_step_adjustment(pred, pred_horvath, age, labels.ix[pts])
mc_adj_c.name = 'Combined, Filtered'

# %%
fig, axs = subplots(1,3, figsize=(15,4))

plot_regression(age.ix[ti(labels == 's1')], mc_adj_c, ax=axs[0])
plot_regression(age.ix[ti(labels == 's3')], mc_adj_c, axs[1])
plot_regression(age.ix[ti(labels == 's2')], mc_adj_c, axs[2])

# %%
dd = pd.DataFrame({(s, m.name): model_fit(m.ix[ti(l2 == s)], age) for s in l2.unique()
                  for m in [m1_adj, m2_adj, mc_adj, mc_adj_c]})
dd = dd.unstack().unstack(1).T
dd
# Out:
#                           EPIC                                Hannum                                Primary Cohort
#                              n     r  error (years)  % error       n     r  error (years)  % error               n     r  error (years)  % error
# Combined, Filtered         170  0.75           3.65     0.06     221  0.92           3.49     0.07              44  0.95           3.07     0.07
# Predicted Age (Combined)   182  0.76           3.60     0.07     242  0.87           4.02     0.08              46  0.94           3.29     0.08
# predicted age (Hannum)     182  0.76           3.64     0.06     242  0.88           4.08     0.08              46  0.93           3.59     0.08
# predicted age (Horvath)    182  0.66           4.66     0.09     242  0.81           5.00     0.10              46  0.93           3.55     0.08

# %%
(mc_adj_c / age).dropna().hist(bins=20)

# %%
m1_adj.name = 'Hannum model'
m2_adj.name = 'Horvath model'
fig, axs = subplots(1,3, figsize=(12,3.5))
ax = axs[0]
plot_regression(m1_adj, m2_adj.ix[ti(diff < .2)], ax=ax, s=30,
                 color='grey', edgecolor='black', alpha=.4)
series_scatter(m1_adj, m2_adj.ix[ti(diff > .2)], color=colors[0], 
               ax=ax, alpha=1, edgecolor='grey', ann=None,
               s=30)
plot_regression(age.ix[ti(labels == 's1')], mc_adj_c, ax=axs[1],
                s=30, color=colors_st[1], alpha=1, edgecolor='grey')
plot_regression(age.ix[ti(labels == 's3')], mc_adj_c, ax=axs[2],
                s=30, color=colors_st[2], alpha=1, edgecolor='grey')
fig.tight_layout()
fig.savefig(FIGDIR + 'f2_top.pdf')
