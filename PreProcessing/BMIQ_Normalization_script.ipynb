# %%
import pandas as pd

# %% [markdown]
# ## BMIQ Normalization

# %% [markdown]
# Here we are running [BMIQ normalization](http://www.ncbi.nlm.nih.gov/pubmed/23175756) on all of our quantile-normalized data together.  I am using the implementation provided by Steve Horvath along with his recent methylation-age paper.  We are doing this as a result of [this paper's](http://www.ncbi.nlm.nih.gov/pubmed/23422812) recomendation to run both quantile normalization and BMIQ in series on the same datasets.

# %%
import pandas as pd

import rpy2.robjects as robjects
from pandas.rpy.common import convert_to_r_dataframe
from pandas.rpy.common import convert_robj

from IPython.display import clear_output

# %% [markdown]
# Load Horvath normalization source into R namespace.

# %% [markdown]
# Read in cell composition adjusted, quantile-normalized beta values and cell counts from the MINFI pipeline.

# %%
c = [u'3001', u'3002', u'3003', u'3004', u'3005', 
     u'3006', u'3007', u'3008', u'3009', u'3010']

# %%
betas = pd.read_hdf('/data_ssd/methylation_norm.h5', 'betas_adj', columns=c)

# %%
gold_standard_ah = pd.read_hdf('/data_ssd/methylation_norm.h5', 'Hannum_gold_standard')

# %%
betas = betas.ix[gold_standard_ah.index]

# %%
if betas.isnull().sum().sum() > 0:
    betas = betas.T.fillna(gold_standard_ah).T

# %%
robjects.r.library('WGCNA');
robjects.r.source("/cellar/users/agross/Data/MethylationAge/Horvath/NORMALIZATION.R");
clear_output()

# %%
df_r = robjects.r.t(convert_to_r_dataframe(betas))
gs = list(gold_standard_ah.ix[betas.index])
gs_r = robjects.FloatVector(gs)

# %%
del betas

# %%
data_n = robjects.r.BMIQcalibration(df_r, gs_r)
data_n = convert_robj(data_n).T
clear_output()

# %%
data_n.columns = data_n.columns.map(lambda s: s.replace('.','-'))
data_n.columns = data_n.columns.map(lambda s: s[1:] if s.startswith('X') else s)

# %%
store = pd.HDFStore('/data_ssd/methylation_norm_tmp.h5')

# %%
ls
# Out:
#                     3001      3002      3003      3004      3005      3006  \
# cg00000029      0.592240  0.510267  0.685360  0.359762  0.453208  0.378323
# cg00000108      0.752802  0.911826  0.907814  0.915458  0.910821  0.708800
# cg00000109      0.757381  0.868124  0.807706  0.883148  0.904858  0.713249
# cg00000165      0.594512  0.338608  0.162821  0.183733  0.531514  0.172554
# cg00000236      0.634071  0.750260  0.749771  0.750806  0.801952  0.585840
# cg00000289      0.639025  0.637054  0.578818  0.538156  0.638393  0.498380
# cg00000292      0.734110  0.795642  0.869419  0.871464  0.668047  0.496161
# cg00000321      0.200406  0.339578  0.287694  0.406807  0.578005  0.477117
# cg00000363      0.173539  0.306196  0.279568  0.452325  0.594190  0.405638
# cg00000622      0.070141  0.074719  0.092488  0.080013  0.079370  0.081252
# cg00000658      0.672533  0.839492  0.823381  0.838775  0.839570  0.617071
# cg00000714      0.262799  0.095491  0.114185  0.181854  0.137535  0.091392
# cg00000721      0.754021  0.873893  0.874656  0.896378  0.885131  0.659826
# cg00000734      0.115377  0.096867  0.111058  0.097950  0.095135  0.105143
# cg00000769      0.154130  0.163744  0.158411  0.153250  0.135388  0.149865
# cg00000807      0.661783  0.836051  0.791858  0.843818  0.792714  0.644693
# cg00000884      0.726000  0.862975  0.862360  0.870452  0.802417  0.659626
# cg00000905      0.187609  0.204014  0.210246  0.198371  0.336889  0.271890
# cg00000924      0.458658  0.502729  0.491602  0.505385  0.421769  0.368584
# cg00000948      0.717198  0.841660  0.844060  0.825202  0.840352  0.642290
# cg00000957      0.703696  0.860297  0.847954  0.860540  0.856040  0.649739
